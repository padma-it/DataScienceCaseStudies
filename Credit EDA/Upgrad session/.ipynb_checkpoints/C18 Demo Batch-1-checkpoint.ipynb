# %%
# Memory issuse: When you have less RAM = 4GB

# Randomly sample the data
# 1000 rows in my data: Take some random 500 rows so that I can easily work on my data without any memory issue

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import random

pd.set_option('display.max_columns', 50)

# %%
df = pd.read_csv("telco_churn.csv")
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
# Filename in the same location as my jupyter notebook
filename = "telco_churn.csv"

# finding the total number of rows in the file without loading the file
num_lines = sum(1 for l in open(filename))

# Sample size: 50%

size = int(num_lines//2)

random.seed(100)
skip_id = random.sample(range(1, num_lines), num_lines - size)

data = pd.read_csv(filename, skiprows = skip_id)

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  9237-HQITU  Female              0      No         No       2          Yes
# 2  6713-OKOMC  Female              0      No         No      10           No
# 3  7892-POOKP  Female              0     Yes         No      28          Yes
# 4  6388-TABGU    Male              0      No        Yes      62          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No     Fiber optic             No           No
# 2  No phone service             DSL            Yes           No
# 3               Yes     Fiber optic             No           No
# 4                No             DSL            Yes          Yes
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
data.shape
# Out:
# (3521, 21)

# %%
random.seed(100)
random.sample(range(1,10), 5)
# Out:
# [3, 8, 4, 2, 7]

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
# Percentage of null data
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
# I wanted to identify which column is continuous and which is categorical
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
# Look at the number of unique categries in a column
df.nunique().sort_values()
# Out:
# Churn                  2
# gender                 2
# SeniorCitizen          2
# Partner                2
# Dependents             2
# PaperlessBilling       2
# PhoneService           2
# Contract               3
# StreamingMovies        3
# StreamingTV            3
# TechSupport            3
# OnlineBackup           3
# OnlineSecurity         3
# InternetService        3
# MultipleLines          3
# DeviceProtection       3
# PaymentMethod          4
# tenure                73
# MonthlyCharges      1585
# TotalCharges        6531
# customerID          7043
# dtype: int64

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
# How we can change the data type
# SeniorCitizen: Object
# TotalCharges: Float

df.loc[:, 'SeniorCitizen'] = df.loc[:, 'SeniorCitizen'].astype(object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   object
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.loc[:, 'TotalCharges'] = df.loc[:, 'TotalCharges'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-99cff62bd6e3> in <module>
# ----> 1 df.loc[:, 'TotalCharges'] = df.loc[:, 'TotalCharges'].astype(float)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ...

# %%
df.TotalCharges.value_counts()
# Out:
#            11
# 20.2       11
# 19.75       9
# 19.9        8
# 19.65       8
#            ..
# 6223.3      1
# 741.5       1
# 1442.6      1
# 3014.65     1
# 1147.45     1
# Name: TotalCharges, Length: 6531, dtype: int64

# %%
# NA, NaN, NULL
#" "

df.TotalCharges = pd.to_numeric(df.TotalCharges, errors = 'coerce')
# All the errors that are my pd.to_numeric function is not able to convert into numeric, it will be converted into NAN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   object
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
# Correlation Part

df.head()
# Churn: Target
# Yes: 1
# No: 0
# Out:
#    customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female             0     Yes         No       1           No
# 1  5575-GNVDE    Male             0      No         No      34          Yes
# 2  3668-QPYBK    Male             0      No         No       2          Yes
# 3  7795-CFOCW    Male             0      No         No      45           No
# 4  9237-HQITU  Female             0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
df.rename({"Churn":'Target'}, axis =1, inplace   = True)

# %%
df.head()
# Out:
#    customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female             0     Yes         No       1           No
# 1  5575-GNVDE    Male             0      No         No      34          Yes
# 2  3668-QPYBK    Male             0      No         No       2          Yes
# 3  7795-CFOCW    Male             0      No         No      45           No
# 4  9237-HQITU  Female             0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
df_1 = df[df['Target']=="Yes"]
df_0 = df[df['Target']=="No"]

# %%
df_0.head()
# Out:
#    customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female             0     Yes         No       1           No
# 1  5575-GNVDE    Male             0      No         No      34          Yes
# 3  7795-CFOCW    Male             0      No         No      45           No
# 6  1452-KIOVK    Male             0      No        Yes      22          Yes
# 7  6713-OKOMC  Female             0      No         No      10           No
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 3  No phone service             DSL            Yes           No
# 6               Yes     Fiber optic             No          Yes
# 7  No phone service             DSL            Yes           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
df_1.corr()
# Out:
#                   tenure  MonthlyCharges  TotalCharges
# tenure          1.000000        0.401286      0.954017
# MonthlyCharges  0.401286        1.000000      0.545772
# TotalCharges    0.954017        0.545772      1.000000

# %%
df_1.corr().unstack().reset_index()
# Out:
#           level_0         level_1         0
# 0          tenure          tenure  1.000000
# 1          tenure  MonthlyCharges  0.401286
# 2          tenure    TotalCharges  0.954017
# 3  MonthlyCharges          tenure  0.401286
# 4  MonthlyCharges  MonthlyCharges  1.000000
# 5  MonthlyCharges    TotalCharges  0.545772
# 6    TotalCharges          tenure  0.954017
# 7    TotalCharges  MonthlyCharges  0.545772
# 8    TotalCharges    TotalCharges  1.000000

# %%
np.ones(corr.shape)
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.],
#        [1., 1., 1.]])

# %%
corr.where(np.triu(np.ones(corr.shape), k=1).astype(np.bool))
# Out:
#                 tenure  MonthlyCharges  TotalCharges
# tenure             NaN        0.401286      0.954017
# MonthlyCharges     NaN             NaN      0.545772
# TotalCharges       NaN             NaN           NaN

# %%
corr = df_1.corr()

corr = corr.where(np.triu(np.ones(corr.shape), k=1).astype(np.bool))
corr
# Out:
#                 tenure  MonthlyCharges  TotalCharges
# tenure             NaN        0.401286      0.954017
# MonthlyCharges     NaN             NaN      0.545772
# TotalCharges       NaN             NaN           NaN

# %%
corrdf = corr.unstack().reset_index()

# %%
corrdf.columns = ['VAR1', 'VAR2', 'Correlation']

# %%
corrdf.head()
# Out:
#              VAR1            VAR2  Correlation
# 0          tenure          tenure          NaN
# 1          tenure  MonthlyCharges          NaN
# 2          tenure    TotalCharges          NaN
# 3  MonthlyCharges          tenure     0.401286
# 4  MonthlyCharges  MonthlyCharges          NaN

# %%
corrdf.dropna(subset = ['Correlation'], inplace = True)

# %%
corrdf['Correlation'] = round(corrdf['Correlation'], 2)
# Since we see correlation as an absolute value, we are converting it into absolute value
corrdf['Correlation'] = corrdf['Correlation'].abs()

# %%
corrdf.sort_values(by = 'Correlation', ascending = False).head(10)
# Out:
#              VAR1            VAR2  Correlation
# 6    TotalCharges          tenure         0.95
# 7    TotalCharges  MonthlyCharges         0.55
# 3  MonthlyCharges          tenure         0.40

# %%
corr = df_2.corr()

corr = corr.where(np.triu(np.ones(corr.shape), k=1).astype(np.bool))
corrdf0 = corr.unstack().reset_index()
corrdf0.columns = ['VAR1', 'VAR2', 'Correlation']
corrdf0.dropna(subset = ['Correlation'], inplace = True)
corrdf0['Correlation'] = round(corrdf0['Correlation'], 2)
# Since we see correlation as an absolute value, we are converting it into absolute value
corrdf0['Correlation_abs'] = corrdf0['Correlation'].abs()
corrdf0.sort_values(by = 'Correlation_abs', ascending = False).head(10)
# Out:
#              VAR1            VAR2  Correlation  Correlation_abs
# 6    TotalCharges          tenure         0.79             0.79
# 7    TotalCharges  MonthlyCharges         0.76             0.76
# 3  MonthlyCharges          tenure         0.33             0.33

# %%
0.9
-0.9

# %%
# Imbalance Percentge:
df.head()
# Out:
#    customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female             0     Yes         No       1           No
# 1  5575-GNVDE    Male             0      No         No      34          Yes
# 2  3668-QPYBK    Male             0      No         No       2          Yes
# 3  7795-CFOCW    Male             0      No         No      45           No
# 4  9237-HQITU  Female             0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
# Imbalace Percentage:

100*df.Target.value_counts()/ len(df)
# Out:
# No     73.463013
# Yes    26.536987
# Name: Target, dtype: float64

# %%
# I wanted to analyse continuous column with respect to the target column

sns.distplot(df_0['MonthlyCharges'], hist = False)# Target = No
sns.distplot(df_1['MonthlyCharges'], hist = False)# Taget = Yes

# %%
# Countplot

sns.countplot(x= 'PaymentMethod', hue = 'Target', data =df)
plt.xticks(rotation = 90)
# Out:
# (array([0, 1, 2, 3]), <a list of 4 Text xticklabel objects>)

# %%
# If you wanted to plot mutiple categorical columns with respect to Target columns: Subplot

df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Target'],
#       dtype='object')

# %%
features = ['gender', 'SeniorCitizen', 'Partner', 'Dependents','StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
       'PaymentMethod']
list(enumerate(features))
# Out:
# [(0, 'gender'),
#  (1, 'SeniorCitizen'),
#  (2, 'Partner'),
#  (3, 'Dependents'),
#  (4, 'StreamingTV'),
#  (5, 'StreamingMovies'),
#  (6, 'Contract'),
#  (7, 'PaperlessBilling'),
#  (8, 'PaymentMethod')]

# %%
features = ['gender', 'SeniorCitizen', 'Partner', 'Dependents','StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
       'PaymentMethod']
plt.figure(figsize = (15, 30))
for i in enumerate(features):
    plt.subplot(5, 2, i[0]+1)
    sns.countplot(x = i[1], hue = 'Target', data = df)
    plt.xticks(rotation = 90)

# %%
df.head()
# Out:
#    customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female             0     Yes         No       1           No
# 1  5575-GNVDE    Male             0      No         No      34          Yes
# 2  3668-QPYBK    Male             0      No         No       2          Yes
# 3  7795-CFOCW    Male             0      No         No      45           No
# 4  9237-HQITU  Female             0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
df.MonthlyCharges.describe()
# Out:
# count    7043.000000
# mean       64.761692
# std        30.090047
# min        18.250000
# 25%        35.500000
# 50%        70.350000
# 75%        89.850000
# max       118.750000
# Name: MonthlyCharges, dtype: float64

# %%
df['MonthlyLable'] = pd.cut(df.MonthlyCharges,[10, 50, 100, 200], labels = ['Low', 'medium', 'High'])

# %%
df.head()
# Out:
#    customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female             0     Yes         No       1           No
# 1  5575-GNVDE    Male             0      No         No      34          Yes
# 2  3668-QPYBK    Male             0      No         No       2          Yes
# 3  7795-CFOCW    Male             0      No         No      45           No
# 4  9237-HQITU  Female             0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...
