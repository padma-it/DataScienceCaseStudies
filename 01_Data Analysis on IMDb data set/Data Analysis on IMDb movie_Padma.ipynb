# %%
# Supress Warnings

import warnings
warnings.filterwarnings('ignore')

# %%
# Import the numpy and pandas packages

import numpy as np
import pandas as pd
# Import matplotlib and setup the figures to display within the notebook
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Task 1: Reading and Inspection
#
# -  ### Subtask 1.1: Import and read
#
# Import and read the movie database. Store it in a variable called `movies`.

# %%
# Write your code for importing the csv file here
movies = pd.read_csv('Movie+Data.csv')
movies
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %% [markdown]
# -  ### Subtask 1.2: Inspect the dataframe
#
# Inspect the dataframe's columns, shapes, variable types etc.

# %%
# Write your code for inspection here
print("Columns present in the movies dataframe:\n\n",movies.columns)
print("\n\nShape(Rows,Columns) of the movies dataframe: ", movies.shape)
print("\n\nInfo of Movies Dataframe: \n")
movies.info() # prints information hence print() not needed
print("\nDatatype of each column:\n\n",movies.dtypes)
# Out:
# Columns present in the movies dataframe:
#
#  Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')
#
#
# Shape(Rows,Columns) of the movies dataframe:  (5043, 28)
#
#
# Info of Movies Dataframe:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
# ...

# %% [markdown]
# ## Task 2: Cleaning the Data
#
# -  ### Subtask 2.1: Inspect Null values
#
# Find out the number of Null values in all the columns and rows. Also, find the percentage of Null values in each column. Round off the percentages upto two decimal places.

# %%
# Write your code for column-wise null count here
print("Column Name    -     Null Values Count")
movies.isnull().sum(axis=0) # isnull() returns boolean values for each row/column and calculate the number of null values
# Out:
# Column Name    -     Null Values Count
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# ...

# %%
# Write your code for row-wise null count here
print("Row No.- Null Values Count")
movies.isnull().sum(axis=1)
# Out:
# Row No.- Null Values Count
# 0        0
# 1        0
# 2        0
# 3        0
# 4       14
#         ..
# 5038     4
# 5039     5
# 5040     4
# 5041     2
# 5042     0
# Length: 5043, dtype: int64

# %%
# Write your code for column-wise null percentages here
original_total_rows_count = len(movies.index) # for percentage calculation in further cells 
print("Column Name       -        Null Values %")
round(((movies.isnull().sum(axis=0) / original_total_rows_count) * 100),2)
# Out:
# Column Name       -        Null Values %
# color                         0.38
# director_name                 2.06
# num_critic_for_reviews        0.99
# duration                      0.30
# director_facebook_likes       2.06
# actor_3_facebook_likes        0.46
# actor_2_name                  0.26
# actor_1_facebook_likes        0.14
# gross                        17.53
# genres                        0.00
# actor_1_name                  0.14
# movie_title                   0.00
# num_voted_users               0.00
# cast_total_facebook_likes     0.00
# actor_3_name                  0.46
# facenumber_in_poster          0.26
# plot_keywords                 3.03
# movie_imdb_link               0.00
# num_user_for_reviews          0.42
# language                      0.24
# country                       0.10
# content_rating                6.01
# budget                        9.76
# title_year                    2.14
# actor_2_facebook_likes        0.26
# ...

# %% [markdown]
# -  ### Subtask 2.2: Drop unecessary columns
#
# For this assignment, you will mostly be analyzing the movies with respect to the ratings, gross collection, popularity of movies, etc. So many of the columns in this dataframe are not required. So it is advised to drop the following columns.
# -  color
# -  director_facebook_likes
# -  actor_1_facebook_likes
# -  actor_2_facebook_likes
# -  actor_3_facebook_likes
# -  actor_2_name
# -  cast_total_facebook_likes
# -  actor_3_name
# -  duration
# -  facenumber_in_poster
# -  content_rating
# -  country
# -  movie_imdb_link
# -  aspect_ratio
# -  plot_keywords

# %%
# Write your code for dropping the columns here. It is advised to keep inspecting the dataframe after each set of operations
print("Columns in Movies Dataframe before dropping: \n", movies.columns) 
drop_column_names = ['color','director_facebook_likes','actor_1_facebook_likes','actor_2_facebook_likes','actor_3_facebook_likes','actor_2_name','cast_total_facebook_likes','actor_3_name','duration','facenumber_in_poster','content_rating','country','movie_imdb_link','aspect_ratio','plot_keywords']
movies.drop(columns=drop_column_names, axis=1, inplace=True)
print("Columns in Movies Dataframe after dropping: \n", movies.columns) # Observe the change in columns
# Out:
# Columns in Movies Dataframe before dropping:
#  Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')
# Columns in Movies Dataframe after dropping:
#  Index(['director_name', 'num_critic_for_reviews', 'gross', 'genres',
#        'actor_1_name', 'movie_title', 'num_voted_users',
#        'num_user_for_reviews', 'language', 'budget', 'title_year',
#        'imdb_score', 'movie_facebook_likes'],
#       dtype='object')

# %% [markdown]
# -  ### Subtask 2.3: Drop unecessary rows using columns with high Null percentages
#
# Now, on inspection you might notice that some columns have large percentage (greater than 5%) of Null values. Drop all the rows which have Null values for such columns.

# %%
# Write your code for dropping the rows here
# Find columns null percentage and find which columns have greater than 5% null values
null_cols = round(((movies.isnull().sum(axis=0) / original_total_rows_count) * 100),2) > 5

# Retain only rows which do not have null values on columns having True from above equation dynamically
movies = movies.loc[~np.isnan(movies.loc[:,null_cols]).any(axis=1)]
movies.reset_index(inplace=True, drop=True) #This step is to set indices in correct order after dropping rows; drop param will drop the added index column;
print("Observe the number of rows got reduced to ", movies.shape)
movies.head()
# Out:
# Observe the number of rows got reduced to  (3891, 13)
#        director_name  num_critic_for_reviews        gross  \
# 0      James Cameron                   723.0  760505847.0
# 1     Gore Verbinski                   302.0  309404152.0
# 2         Sam Mendes                   602.0  200074175.0
# 3  Christopher Nolan                   813.0  448130642.0
# 4     Andrew Stanton                   462.0   73058679.0
#
#                             genres     actor_1_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1         Action|Adventure|Fantasy      Johnny Depp
# 2        Action|Adventure|Thriller  Christoph Waltz
# 3                  Action|Thriller        Tom Hardy
# 4          Action|Adventure|Sci-Fi     Daryl Sabara
#
#                                  movie_title  num_voted_users  \
# 0                                    Avatar            886204
# 1  Pirates of the Caribbean: At World's End            471220
# ...

# %% [markdown]
# -  ### Subtask 2.4: Fill NaN values
#
# You might notice that the `language` column has some NaN values. Here, on inspection, you will see that it is safe to replace all the missing values with `'English'`.

# %%
# Write your code for filling the NaN values in the 'language' column here
print("Null values in language column before impute: " , movies.loc[:,'language'].isnull().sum())
movies["language"].fillna("English", inplace = True)
print("Null values in language column after impute: " , movies.loc[:,'language'].isnull().sum())
# Out:
# Null values in language column before impute:  3
# Null values in language column after impute:  0

# %% [markdown]
# -  ### Subtask 2.5: Check the number of retained rows
#
# You might notice that two of the columns viz. `num_critic_for_reviews` and `actor_1_name` have small percentages of NaN values left. You can let these columns as it is for now. Check the number and percentage of the rows retained after completing all the tasks above.

# %%
# Write your code for checking number of retained rows here
# Get the new column-wise null percentages and observe the differences
new_total_rows_count = len(movies.index)
print("Columns which still have null values:{0}\nAll columns Overview:\n{1} ".format(movies.columns[round(((movies.isnull().sum(axis=0) / new_total_rows_count) * 100),2) > 0], round(((movies.isnull().sum(axis=0) / new_total_rows_count) * 100),2)))

# Get new total number of rows
print("\nPercentage of rows retained: ", round(((new_total_rows_count / original_total_rows_count ) * 100),2))
# Out:
# Columns which still have null values:Index(['num_critic_for_reviews', 'actor_1_name'], dtype='object')
# All columns Overview:
# director_name             0.00
# num_critic_for_reviews    0.03
# gross                     0.00
# genres                    0.00
# actor_1_name              0.08
# movie_title               0.00
# num_voted_users           0.00
# num_user_for_reviews      0.00
# language                  0.00
# budget                    0.00
# title_year                0.00
# imdb_score                0.00
# movie_facebook_likes      0.00
# dtype: float64
#
# Percentage of rows retained:  77.16

# %% [markdown]
# **Checkpoint 1:** You might have noticed that we still have around `77%` of the rows!

# %% [markdown]
# ## Task 3: Data Analysis
#
# -  ### Subtask 3.1: Change the unit of columns
#
# Convert the unit of the `budget` and `gross` columns from `$` to `million $`.

# %%
# Write your code for unit conversion here
movies['gross'] = movies['gross'] / 1000000
movies['budget'] = movies['budget'] / 1000000
movies.head()
# Out:
#        director_name  num_critic_for_reviews       gross  \
# 0      James Cameron                   723.0  760.505847
# 1     Gore Verbinski                   302.0  309.404152
# 2         Sam Mendes                   602.0  200.074175
# 3  Christopher Nolan                   813.0  448.130642
# 4     Andrew Stanton                   462.0   73.058679
#
#                             genres     actor_1_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1         Action|Adventure|Fantasy      Johnny Depp
# 2        Action|Adventure|Thriller  Christoph Waltz
# 3                  Action|Thriller        Tom Hardy
# 4          Action|Adventure|Sci-Fi     Daryl Sabara
#
#                                  movie_title  num_voted_users  \
# 0                                    Avatar            886204
# 1  Pirates of the Caribbean: At World's End            471220
# 2                                   Spectre            275868
# ...

# %% [markdown]
# -  ### Subtask 3.2: Find the movies with highest profit
#
#     1. Create a new column called `profit` which contains the difference of the two columns: `gross` and `budget`.
#     2. Sort the dataframe using the `profit` column as reference.
#     3. Plot `profit` (y-axis) vs `budget` (x- axis) and observe the outliers using the appropriate chart type.
#     4. Extract the top ten profiting movies in descending order and store them in a new dataframe - `top10`

# %%
# Write your code for creating the profit column here
movies['profit'] = movies['gross'] - movies['budget']
movies.head()
# Out:
#        director_name  num_critic_for_reviews       gross  \
# 0      James Cameron                   723.0  760.505847
# 1     Gore Verbinski                   302.0  309.404152
# 2         Sam Mendes                   602.0  200.074175
# 3  Christopher Nolan                   813.0  448.130642
# 4     Andrew Stanton                   462.0   73.058679
#
#                             genres     actor_1_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1         Action|Adventure|Fantasy      Johnny Depp
# 2        Action|Adventure|Thriller  Christoph Waltz
# 3                  Action|Thriller        Tom Hardy
# 4          Action|Adventure|Sci-Fi     Daryl Sabara
#
#                                  movie_title  num_voted_users  \
# 0                                    Avatar            886204
# 1  Pirates of the Caribbean: At World's End            471220
# 2                                   Spectre            275868
# ...

# %%
# Write your code for sorting the dataframe here and reset index to have the dataframe numbered by profit order
movies = movies.sort_values('profit', ascending = False).reset_index(drop=True)
movies.head(5)
# Out:
#       director_name  num_critic_for_reviews       gross  \
# 0     James Cameron                   723.0  760.505847
# 1   Colin Trevorrow                   644.0  652.177271
# 2     James Cameron                   315.0  658.672302
# 3      George Lucas                   282.0  460.935665
# 4  Steven Spielberg                   215.0  434.949459
#
#                              genres         actor_1_name  \
# 0   Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 1  Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# 2                     Drama|Romance    Leonardo DiCaprio
# 3   Action|Adventure|Fantasy|Sci-Fi        Harrison Ford
# 4                     Family|Sci-Fi         Henry Thomas
#
#                            movie_title  num_voted_users  num_user_for_reviews  \
# 0                              Avatar            886204                3054.0
# 1                      Jurassic World            418214                1290.0
# ...

# %%
# Write code for profit vs budget plot here - Scatter plot to identify the outliers

plt.style.use('seaborn-whitegrid') # style of the plot
plt.scatter(x=movies['budget'], y=movies['profit'], edgecolor='orange')
plt.title("IMDb Movies Profit vs Budget", fontdict={'fontsize' : 20, 'fontweight' : 5, 'color' : 'Blue'})
plt.xlabel("Budget",fontdict={'fontsize' : 10, 'fontweight' : 3, 'color' : 'Blue'})
plt.ylabel("Profit",fontdict={'fontsize' : 10, 'fontweight' : 3, 'color' : 'Blue'})

outliers = movies.loc[movies.budget > 4000,['budget','profit','movie_title']].reset_index(drop=True)#selecting values for annotation

# Annotate only outlier values in the bars - position of label(x,y) is at (i-0.3),(df_by_decade['num_user_for_reviews'][i]+10000) for better visibility
for i in range(0,len(outliers)):    
    plt.annotate("Movie Title:"+outliers.loc[i,'movie_title'], (outliers.loc[i,'budget']+100,outliers.loc[i,'profit']+100 ))
plt.show()

# %% [markdown]
# #### OBSERVATION:
#
# From the above scatter plot, we can see that __movie : The Host__ is an outlier with respect to budget and profit of the movie.

# %%
top10 = movies.iloc[0:10,:] # Write your code to get the top 10 profiting movies here
top10 # Observe that The Avengers is a duplicate here
# Out:
#        director_name  num_critic_for_reviews       gross  \
# 0      James Cameron                   723.0  760.505847
# 1    Colin Trevorrow                   644.0  652.177271
# 2      James Cameron                   315.0  658.672302
# 3       George Lucas                   282.0  460.935665
# 4   Steven Spielberg                   215.0  434.949459
# 5        Joss Whedon                   703.0  623.279547
# 6        Joss Whedon                   703.0  623.279547
# 7       Roger Allers                   186.0  422.783777
# 8       George Lucas                   320.0  474.544677
# 9  Christopher Nolan                   645.0  533.316061
#
#                                      genres         actor_1_name  \
# 0           Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 1          Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# 2                             Drama|Romance    Leonardo DiCaprio
# 3           Action|Adventure|Fantasy|Sci-Fi        Harrison Ford
# ...

# %% [markdown]
# -  ### Subtask 3.3: Drop duplicate values
#
# After you found out the top 10 profiting movies, you might have noticed a duplicate value. So, it seems like the dataframe has duplicate values as well. Drop the duplicate values from the dataframe and repeat `Subtask 3.2`. Note that the same `movie_title` can be there in different languages.

# %%
# Write your code for dropping duplicate values here
print("With duplicates: " ,movies.shape)
# If we have to drop the rows only if all the columns are same, we could use below:
#movies.drop_duplicates(inplace=True)
# Since the task mentions same movie_title could be in different languages, I am interpreting that this imposes restriction 
# that same movie cannot be in same language and hence dropping the duplicates based on the below subset.
movies.drop_duplicates(subset=['movie_title','language'], keep = 'first',inplace=True)
print("After removing duplicates: ",movies.shape)

movies.reset_index(inplace=True, drop=True) #After row deletion, reset the index accordingly
movies.head()
# Out:
# With duplicates:  (3891, 14)
# After removing duplicates:  (3790, 14)
#       director_name  num_critic_for_reviews       gross  \
# 0     James Cameron                   723.0  760.505847
# 1   Colin Trevorrow                   644.0  652.177271
# 2     James Cameron                   315.0  658.672302
# 3      George Lucas                   282.0  460.935665
# 4  Steven Spielberg                   215.0  434.949459
#
#                              genres         actor_1_name  \
# 0   Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 1  Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# 2                     Drama|Romance    Leonardo DiCaprio
# 3   Action|Adventure|Fantasy|Sci-Fi        Harrison Ford
# 4                     Family|Sci-Fi         Henry Thomas
#
#                            movie_title  num_voted_users  num_user_for_reviews  \
# 0                              Avatar            886204                3054.0
# ...

# %%
# Write code for repeating subtask 2 here - to get the top 10 profiting movies 
#movies.sort_values('profit', ascending = False, inplace=True) # Sort by profit
top10 = movies.iloc[0:10,:] 
top10 #Print all top10 movies to observe 2 movies by James Cameron
# Out:
#        director_name  num_critic_for_reviews       gross  \
# 0      James Cameron                   723.0  760.505847
# 1    Colin Trevorrow                   644.0  652.177271
# 2      James Cameron                   315.0  658.672302
# 3       George Lucas                   282.0  460.935665
# 4   Steven Spielberg                   215.0  434.949459
# 5        Joss Whedon                   703.0  623.279547
# 6       Roger Allers                   186.0  422.783777
# 7       George Lucas                   320.0  474.544677
# 8  Christopher Nolan                   645.0  533.316061
# 9          Gary Ross                   673.0  407.999255
#
#                                      genres         actor_1_name  \
# 0           Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 1          Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# 2                             Drama|Romance    Leonardo DiCaprio
# 3           Action|Adventure|Fantasy|Sci-Fi        Harrison Ford
# ...

# %% [markdown]
# **Checkpoint 2:** You might spot two movies directed by `James Cameron` in the list.

# %% [markdown]
# -  ### Subtask 3.4: Find IMDb Top 250
#
#     1. Create a new dataframe `IMDb_Top_250` and store the top 250 movies with the highest IMDb Rating (corresponding to the column: `imdb_score`). Also make sure that for all of these movies, the `num_voted_users` is greater than 25,000.
# Also add a `Rank` column containing the values 1 to 250 indicating the ranks of the corresponding films.
#     2. Extract all the movies in the `IMDb_Top_250` dataframe which are not in the English language and store them in a new dataframe named `Top_Foreign_Lang_Film`.

# %%
# Write your code for extracting the top 250 movies as per the IMDb score here. Make sure that you store it in a new dataframe and name that dataframe as 'IMDb_Top_250'
IMDb_Top_250 = movies.loc[(movies['num_voted_users'] > 25000), :].nlargest(250, 'imdb_score')
IMDb_Top_250['Rank'] = IMDb_Top_250['imdb_score'].rank(ascending = False,method='first').astype('int') # ranks 1 to 250; Param first gives ranks according to the order in the dataframe, if more than one movie have same score
print(IMDb_Top_250.shape)
IMDb_Top_250
# Out:
# (250, 15)
#              director_name  num_critic_for_reviews       gross  \
# 1705        Frank Darabont                   199.0   28.341469
# 134   Francis Ford Coppola                   208.0  134.821952
# 8        Christopher Nolan                   645.0  533.316061
# 589   Francis Ford Coppola                   149.0   57.300000
# 17           Peter Jackson                   328.0  377.019252
# ...                    ...                     ...         ...
# 2950            Tim Burton                   148.0    5.887457
# 3224       Roger Donaldson                   126.0    5.128124
# 3399         Cameron Crowe                   149.0   32.522352
# 3426       Nick Cassavetes                   177.0    0.064286
# 3467           Yimou Zhang                   283.0    0.084961
#
#                               genres            actor_1_name  \
# 1705                     Crime|Drama          Morgan Freeman
# 134                      Crime|Drama               Al Pacino
# ...

# %%
# Write your code to extract top foreign language films from 'IMDb_Top_250' here
Top_Foreign_Lang_Film = IMDb_Top_250.loc[IMDb_Top_250['language']!='English']
print(Top_Foreign_Lang_Film.shape)
Top_Foreign_Lang_Film # prints all rows to observe if Veer-Zaara is present
# Out:
# (38, 15)
#                          director_name  num_critic_for_reviews       gross  \
# 1631                      Sergio Leone                   181.0    6.100000
# 1663                Fernando Meirelles                   214.0    7.563397
# 2239                    Akira Kurosawa                   153.0    0.269061
# 2754                    Hayao Miyazaki                   246.0   10.049886
# 1440  Florian Henckel von Donnersmarck                   215.0   11.284657
# 1897                      Majid Majidi                    46.0    0.925402
# 1560                    Asghar Farhadi                   354.0    7.098492
# 2125                    Chan-wook Park                   305.0    2.181290
# 2322                 Wolfgang Petersen                    96.0   11.433134
# 2915                    S.S. Rajamouli                    44.0    6.498000
# 3596                Jean-Pierre Jeunet                   242.0   33.201661
# ...

# %% [markdown]
# **Checkpoint 3:** Can you spot `Veer-Zaara` in the dataframe?

# %% [markdown]
# - ### Subtask 3.5: Find the best directors
#
#     1. Group the dataframe using the `director_name` column.
#     2. Find out the top 10 directors for whom the mean of `imdb_score` is the highest and store them in a new dataframe `top10director`.  Incase of a tie in IMDb score between two directors, sort them alphabetically.

# %%
# Write your code for extracting the top 10 directors here
# Create a groupby object and apply mean function; 
# rename the mean applied column; 
# sort the resultant dataframe; 
# Get only top 10 directors and reset the index
top10director = movies.groupby('director_name').aggregate({'imdb_score':np.mean}).rename(columns={'imdb_score':'Mean IMDb score'}).sort_values(['Mean IMDb score', 'director_name'], ascending=[False,True]).iloc[0:10].reset_index()

top10director
# Out:
#            director_name  Mean IMDb score
# 0        Charles Chaplin         8.600000
# 1              Tony Kaye         8.600000
# 2       Alfred Hitchcock         8.500000
# 3        Damien Chazelle         8.500000
# 4           Majid Majidi         8.500000
# 5             Ron Fricke         8.500000
# 6           Sergio Leone         8.433333
# 7      Christopher Nolan         8.425000
# 8         Asghar Farhadi         8.400000
# 9  Marius A. Markevicius         8.400000

# %% [markdown]
# **Checkpoint 4:** No surprises that `Damien Chazelle` (director of Whiplash and La La Land) is in this list.

# %% [markdown]
# -  ### Subtask 3.6: Find popular genres
#
# You might have noticed the `genres` column in the dataframe with all the genres of the movies seperated by a pipe (`|`). Out of all the movie genres, the first two are most significant for any film.
#
# 1. Extract the first two genres from the `genres` column and store them in two new columns: `genre_1` and `genre_2`. Some of the movies might have only one genre. In such cases, extract the single genre into both the columns, i.e. for such movies the `genre_2` will be the same as `genre_1`.
# 2. Group the dataframe using `genre_1` as the primary column and `genre_2` as the secondary column.
# 3. Find out the 5 most popular combo of genres by finding the mean of the gross values using the `gross` column and store them in a new dataframe named `PopGenre`.

# %%
# Write your code for extracting the first two genres of each movie here
genre_df = movies['genres'].str.split("|", expand = True)
movies['genre_1'] = genre_df.loc[:,0] # Add genre1 column
movies['genre_2'] = genre_df.loc[:,1] # Add genre2 column

single_genred_movies = movies['genre_2'].isnull()
print("Total number of movies with a single genre: ", len(movies.loc[single_genred_movies]) )
movies.loc[single_genred_movies,'genre_2'] = movies['genre_1'] #  Assign genre 1 to genre 2 for single-genred movies
print("Total number of movies with a single genre: ", len(movies.loc[movies['genre_2'].isnull()]) )
# Out:
# Total number of movies with a single genre:  379
# Total number of movies with a single genre:  0

# %%
# Write your code for grouping the dataframe here
movies_by_segment = movies.groupby(['genre_1', 'genre_2'])

# %%
# Write your code for getting the 5 most popular combo of genres here
PopGenre = movies_by_segment['gross'].mean().sort_values(ascending=False).iloc[0:5].reset_index()
PopGenre
# Out:
#      genre_1    genre_2       gross
# 0     Family     Sci-Fi  434.949459
# 1  Adventure     Sci-Fi  228.627758
# 2  Adventure  Animation  115.949069
# 3  Adventure     Family  110.942298
# 4     Action  Adventure  107.880651

# %% [markdown]
# **Checkpoint 5:** Well, as it turns out. `Family + Sci-Fi` is the most popular combo of genres out there!

# %% [markdown]
# -  ### Subtask 3.7: Find the critic-favorite and audience-favorite actors
#
#     1. Create three new dataframes namely, `Meryl_Streep`, `Leo_Caprio`, and `Brad_Pitt` which contain the movies in which the actors: 'Meryl Streep', 'Leonardo DiCaprio', and 'Brad Pitt' are the lead actors. Use only the `actor_1_name` column for extraction. Also, make sure that you use the names 'Meryl Streep', 'Leonardo DiCaprio', and 'Brad Pitt' for the said extraction.
#     2. Append the rows of all these dataframes and store them in a new dataframe named `Combined`.
#     3. Group the combined dataframe using the `actor_1_name` column.
#     4. Find the mean of the `num_critic_for_reviews` and `num_users_for_review` and identify the actors which have the highest mean.
#     5. Observe the change in number of voted users over decades using a bar chart. Create a column called `decade` which represents the decade to which every movie belongs to. For example, the  `title_year`  year 1923, 1925 should be stored as 1920s. Sort the dataframe based on the column `decade`, group it by `decade` and find the sum of users voted in each decade. Store this in a new data frame called `df_by_decade`.

# %%
# Write your code for creating three new dataframes here

Meryl_Streep = movies.loc[movies['actor_1_name']=='Meryl Streep'] # Include all movies in which Meryl_Streep is the lead
Meryl_Streep
# Out:
#        director_name  num_critic_for_reviews       gross  \
# 248    David Frankel                   208.0  124.732962
# 435   Sydney Pollack                    66.0   87.100000
# 457      Nora Ephron                   252.0   94.125426
# 746    David Frankel                   234.0   63.536011
# 869     Nancy Meyers                   187.0  112.703470
# 1163  Phyllida Lloyd                   331.0   29.959436
# 1173  Stephen Daldry                   174.0   41.597830
# 1400   Robert Altman                   211.0   20.338609
# 1821   Curtis Hanson                    42.0   46.815748
# 2623   Carl Franklin                    64.0   23.209440
# 3231  Robert Redford                   227.0   14.998070
#
#                                genres  actor_1_name  \
# 248              Comedy|Drama|Romance  Meryl Streep
# 435           Biography|Drama|Romance  Meryl Streep
# 457           Biography|Drama|Romance  Meryl Streep
# 746              Comedy|Drama|Romance  Meryl Streep
# ...

# %%
Leo_Caprio = movies.loc[movies['actor_1_name']=='Leonardo DiCaprio'] # Include all movies in which Leo_Caprio is the lead
Leo_Caprio
# Out:
#               director_name  num_critic_for_reviews       gross  \
# 2             James Cameron                   315.0  658.672302
# 128       Christopher Nolan                   642.0  292.568851
# 173        Steven Spielberg                   194.0  164.435221
# 387       Quentin Tarantino                   765.0  162.804648
# 522   Alejandro G. Iñárritu                   556.0  183.635922
# 532         Martin Scorsese                   490.0  127.968405
# 612         Martin Scorsese                   352.0  132.373442
# 646            Baz Luhrmann                   490.0  144.812796
# 786            Baz Luhrmann                   106.0   46.338728
# 1008        Randall Wallace                    83.0   56.876365
# 1166        Martin Scorsese                   606.0  116.866727
# 1788         Clint Eastwood                   392.0   37.304950
# 2660        Martin Scorsese                   267.0  102.608827
# 2842             Jerry Zaks                    45.0   12.782508
# ...

# %%
Brad_Pitt = movies.loc[movies['actor_1_name']=='Brad Pitt'] # Include all movies in which Brad_Pitt is the lead
Brad_Pitt
# Out:
#               director_name  num_critic_for_reviews       gross  \
# 223       Steven Soderbergh                   186.0  183.405771
# 369              Doug Liman                   233.0  186.336103
# 575             Neil Jordan                   120.0  105.264608
# 1141             David Ayer                   406.0   85.707116
# 1212      Steven Soderbergh                   198.0  125.531634
# 1439  Alejandro G. Iñárritu                   285.0   34.300771
# 2006         Andrew Dominik                   414.0   14.938570
# 2108             Tony Scott                   122.0   12.281500
# 2792    Angelina Jolie Pitt                   131.0    0.531009
# 3182        Terrence Malick                   584.0   13.303319
# 3284          David Fincher                   362.0  127.490802
# 3379          David Fincher                   315.0   37.023395
# 3383         Andrew Dominik                   273.0    3.904982
# 3480    Jean-Jacques Annaud                    76.0   37.901509
# ...

# %%
# Write your code for combining the three dataframes here
Combined = Meryl_Streep.append([Leo_Caprio,Brad_Pitt])
Combined
# Out:
#               director_name  num_critic_for_reviews       gross  \
# 248           David Frankel                   208.0  124.732962
# 435          Sydney Pollack                    66.0   87.100000
# 457             Nora Ephron                   252.0   94.125426
# 746           David Frankel                   234.0   63.536011
# 869            Nancy Meyers                   187.0  112.703470
# 1163         Phyllida Lloyd                   331.0   29.959436
# 1173         Stephen Daldry                   174.0   41.597830
# 1400          Robert Altman                   211.0   20.338609
# 1821          Curtis Hanson                    42.0   46.815748
# 2623          Carl Franklin                    64.0   23.209440
# 3231         Robert Redford                   227.0   14.998070
# 2             James Cameron                   315.0  658.672302
# 128       Christopher Nolan                   642.0  292.568851
# 173        Steven Spielberg                   194.0  164.435221
# ...

# %%
# Write your code for grouping the combined dataframe here
df_by_segment = Combined.groupby('actor_1_name')
df_by_segment

# %%
# Write the code for finding the mean of critic reviews and audience reviews here

# Create a groupby object and apply mean functions on two columns; 
# rename the mean applied columns; 
# sort the resultant dataframe; 
# Observe Leonardo is the top on both lists

Combined_DF_Actor_Grouped = df_by_segment.aggregate({'num_critic_for_reviews':np.mean,'num_user_for_reviews':np.mean}).rename(columns={'num_critic_for_reviews':'Mean num_critic_for_reviews', 'num_user_for_reviews':'Mean num_user_for_reviews'}).sort_values(['Mean num_critic_for_reviews','Mean num_user_for_reviews'],ascending=False)

Combined_DF_Actor_Grouped
# Out:
#                    Mean num_critic_for_reviews  Mean num_user_for_reviews
# actor_1_name
# Leonardo DiCaprio                   322.200000                 922.550000
# Brad Pitt                           245.000000                 742.352941
# Meryl Streep                        181.454545                 297.181818

# %% [markdown]
# **Checkpoint 6:** `Leonardo` has aced both the lists!

# %%
# Write the code for calculating decade here
# calculate decade by converting it to int; 1923
# and then divide by 10 will give modulo value (1923%10 -> 3)
# subtract that from the actual year (1923.0-3 = 1920.0)
# convert to int to trim out the decimals and then convert to string and add 's' at the end
movies['decade'] = (movies['title_year'] - (movies['title_year'].astype(int))%10).astype(int).astype(str) + 's'
movies.sort_values(by='decade', inplace=True)
movies
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 1776     Harry Beaumont                    36.0    2.808000
# 1736  Harry F. Millarde                     1.0    3.000000
# 2569         Fritz Lang                   260.0    0.026435
# 1089     Victor Fleming                   213.0   22.202612
# 53       Victor Fleming                   157.0  198.655278
# ...                 ...                     ...         ...
# 2772          Rob Cohen                   211.0   25.863915
# 1108    Morgan Spurlock                    83.0   28.873374
# 2764   William Friedkin                   376.0    1.987762
# 1096         Adam McKay                   265.0  119.219978
# 1894        Jeff Wadlow                   350.0   28.751715
#
#                                 genres         actor_1_name  \
# 1776                   Musical|Romance           Anita Page
# 1736                       Crime|Drama         Stephen Carr
# 2569                      Drama|Sci-Fi        Brigitte Helm
# ...

# %%
# Write your code for creating the data frame df_by_decade here 
# Create groupby and rename the column 
df_by_decade = pd.DataFrame(movies.groupby('decade')["num_user_for_reviews"].sum()).rename(columns={'num_user_for_reviews':'Total num_user_for_reviews'}).reset_index()
df_by_decade
# Out:
#   decade  Total num_user_for_reviews
# 0  1920s                       485.0
# 1  1930s                      1849.0
# 2  1940s                       928.0
# 3  1950s                      1854.0
# 4  1960s                      9424.0
# 5  1970s                     19557.0
# 6  1980s                     50025.0
# 7  1990s                    206419.0
# 8  2000s                    636193.0
# 9  2010s                    291094.0

# %%
# Write your code for plotting number of voted users vs decade - using matplotlib
plt.figure(figsize=(15,15))
plt.subplot(121)
plt.bar(x=df_by_decade['decade'], height=df_by_decade['Total num_user_for_reviews'],color = "steelblue", edgecolor = "orange")

plt.style.use('Solarize_Light2')
plt.xlabel("Decade",fontdict={'fontsize' : 10, 'fontweight' : 3, 'color' : 'Blue'})
plt.ylabel("Total number of user reviews",fontdict={'fontsize' : 10, 'fontweight' : 3, 'color' : 'Blue'})
plt.title("Total number of user reviews trend over decades", fontdict={'fontsize' : 15, 'fontweight' : 5, 'color' : 'Blue'}) # styling with dictionary

tick_values = np.arange(0,700000,50000)
tick_labels = ["0L","5L", "10L","15L", "20L","25L", "30L", "35L","40L", "45L", "50L", "55L","60L","65L"]
plt.yticks(tick_values, tick_labels) # Added granular yticks for better visibility of bars
# Add values in the bars - position of label(x,y) is at (i-0.3),(df_by_decade['num_user_for_reviews'][i]+10000) for better visibility
for i in range(10):
    plt.text(i-0.3,df_by_decade['Total num_user_for_reviews'][i]+10000,int(df_by_decade['Total num_user_for_reviews'][i]))

# Write your code for plotting number of voted users vs decade - using seaborn and log scale for more visibility of bars
plt.subplot(122)
plt.yscale('log')
sns.barplot(x='decade', y='Total num_user_for_reviews', data=df_by_decade)
plt.title("Total number of user reviews trend over decades")
for i in range(10):
    plt.text(i-0.4,df_by_decade['Total num_user_for_reviews'][i]+1000,int(df_by_decade['Total num_user_for_reviews'][i]))
plt.show()

# %% [markdown]
# #### OBSERVATION:
#
# - From the graphs above, it can be seen that the __trend of users reviewing is increasing over the decades__
# - Since we are in the decade of 2010s, it is expected to increase in the future as well!
